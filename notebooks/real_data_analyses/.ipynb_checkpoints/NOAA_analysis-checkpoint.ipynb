# %%
import pandas as pd
import numpy as np

# %%
# import topological analysis functions

# %%
import os 
import sys
sys.path.append('../data/NOAA_Temperature/')

# %%
sys.executable
# Out:
# '/Users/timothysudijono/anaconda3/envs/mypython3/bin/python3'

# %%
all_stations = set()

for year in [2016,2017,2018,2019]:
    data_path = '/Users/timothysudijono/projects/Research/dynamic_networks/data/NOAA_Temperature/%s/' % year
    stations = set([x.split('.')[0] for x in os.listdir(data_path)])
    all_stations = all_stations.union(stations)

    
    
STATION_LIST = sorted(list(all_stations))[::10]
STATION_LIST = [str(x) + '.csv' for x in STATION_LIST]

# %%
len(list(all_stations)[::20])
# Out:
# 674

# %%
def getYearData(year):
    
    data_path = '/Users/timothysudijono/projects/Research/dynamic_networks/data/NOAA_Temperature/%s/' % year
    full_data = pd.DataFrame(index = pd.date_range('01-01-%s'%year,'12-31-%s'%year))
    location_map = {}

    for station in STATION_LIST:
        #print('Analyzing Station %s'%station)
        try:
            df = pd.read_csv(data_path + station)
            temps = df.set_index('DATE').loc[:,['TEMP']]
            temps.index = pd.to_datetime(temps.index) ### important here.
            location = df.loc[:,['LATITUDE','LONGITUDE']].mean(skipna = True).values

            station_number = station.split('.')[0]

            location_map[station_number] = location
            full_data['%s'%station_number] = temps.TEMP
        except FileNotFoundError:
            
            station_number = station.split('.')[0]
            full_data['%s'%station_number] = np.nan
        
    return full_data, location_map

# %%
year_aggregated_data = pd.DataFrame()
locations = {}
for year in [2016,2017,2018,2019]:
    print(year)
    temp_data, location_map = getYearData(year)
    year_aggregated_data = year_aggregated_data.append(temp_data)
    locations.update(location_map)
# Out:
# 2016
# 2017
# 2018
# 2019

# %%
year_aggregated_data.shape
# Out:
# (1461, 1348)

# %%
year_aggregated_data
# Out:
#             00702699999  01007099999  01023199999  01037099999  01058099999  \
# 2016-01-01          NaN         36.3         45.3         37.5         27.2
# 2016-01-02          NaN         34.3         40.6         32.1         23.3
# 2016-01-03          NaN         36.8         34.3         22.7         16.0
# 2016-01-04          NaN         29.4         27.6         11.2         -4.7
# 2016-01-05          NaN         20.4         31.5          6.5        -13.5
# ...                 ...          ...          ...          ...          ...
# 2019-12-27          NaN         21.9          NaN         16.0          6.1
# 2019-12-28          NaN         20.0          NaN         32.1         13.1
# 2019-12-29          NaN         15.3          NaN         39.5         26.5
# 2019-12-30          NaN          8.0          NaN         30.4         21.7
# 2019-12-31          NaN          6.1          NaN         27.6         17.4
#
#             01084099999  01088799999  01112099999  01135099999  01152099999  \
# 2016-01-01         26.4         45.2         39.6         36.0         42.1
# 2016-01-02         23.6         44.2         35.1         30.8         38.2
# 2016-01-03         21.8         35.8         28.1         18.5         28.6
# 2016-01-04         -3.8         35.1         20.3         12.6         17.6
# 2016-01-05         -6.1         35.4         21.6         10.6         20.4
# ...                 ...          ...          ...          ...          ...
# 2019-12-27          7.6         43.6         31.5         19.6         28.6
# 2019-12-28         22.6         45.7         39.8         28.9         39.0
# 2019-12-29         30.4         48.8         44.8         40.9         43.6
# 2019-12-30         27.2         46.9         42.6         38.2         38.9
# 2019-12-31         18.3         44.5         39.0         34.6         36.6
#
#             ...  99999953182  99999954783  99999954856  99999963829  \
# 2016-01-01  ...         21.8         31.2          NaN         55.8
# 2016-01-02  ...         29.9         30.0          NaN         47.7
# 2016-01-03  ...         33.1         33.2          NaN         46.5
# 2016-01-04  ...         33.3         24.9          NaN         46.8
# 2016-01-05  ...         33.3         13.5          NaN         41.5
# ...         ...          ...          ...          ...          ...
# 2019-12-27  ...         31.8         44.0         55.0         61.4
# 2019-12-28  ...         37.6         44.3         40.3         66.0
# 2019-12-29  ...         31.0         38.1         47.6         70.1
# 2019-12-30  ...         29.3         45.6         49.5         66.1
# 2019-12-31  ...         28.4         39.1         34.1         49.7
#
#             99999963867  99999963897  99999992821  99999994044  99999994081  \
# 2016-01-01         37.1         45.6         74.8         23.6         21.4
# 2016-01-02         36.8         42.3         67.9         33.4         19.9
# 2016-01-03         35.9         41.1         60.6         37.0         14.1
# 2016-01-04         35.1         41.0         54.9         35.5         16.2
# 2016-01-05         31.4         36.6         62.1         40.1         16.5
# ...                 ...          ...          ...          ...          ...
# 2019-12-27         52.7         56.7         69.8         25.7         21.5
# 2019-12-28         59.2         61.1         71.5         25.3         21.4
# 2019-12-29         65.0         68.2         73.6         23.1         22.1
# 2019-12-30         53.0         58.0         74.3         22.3         22.2
# 2019-12-31         41.9         44.0         65.4         29.4         22.1
#
#             99999996404
# 2016-01-01         20.9
# 2016-01-02          9.0
# 2016-01-03         19.9
# 2016-01-04          9.8
# 2016-01-05         -9.4
# ...                 ...
# 2019-12-27        -23.6
# 2019-12-28        -23.3
# 2019-12-29        -23.0
# 2019-12-30        -13.9
# 2019-12-31          5.1
#
# [1461 rows x 1348 columns]

# %% [markdown]
# ## Visualize dynamic network? On globe / picture of the US

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (11,5))
ax1.plot(year_aggregated_data.isna().sum(axis = 1))
ax1.set_ylabel('# Stations with Missing Data')
ax1.set_xlabel('Date')
ax1.set_title('Missing Station Data by Date')
fig.autofmt_xdate(rotation=45)
## There's no data for 2018? - all good. DateTime Index issues.

ax2.hist(year_aggregated_data.isna().sum(axis = 0))
ax2.set_xlabel('# Dates with missing data')
ax2.set_ylabel('# Stations')
ax2.set_title('Distribution of stations by missing days')
# Out:
# Text(0.5, 1.0, 'Distribution of stations by missing days')

# %% [markdown]
# ## Data visualization

# %%
# %matplotlib inline

# %%
print(year_aggregated_data.shape)
# Out:
# (1461, 1348)

# %%
#year_aggregated_data.fillna(0).mean(axis = 1).plot()

# %%
import matplotlib.pyplot as plt
for i in range(200,220):
    plt.plot(year_aggregated_data.iloc[:,i].values)
    plt.show()

# %%
year_aggregated_data.head()
# Out:
#             00702699999  01007099999  01023199999  01037099999  01058099999  \
# 2016-01-01          NaN         36.3         45.3         37.5         27.2
# 2016-01-02          NaN         34.3         40.6         32.1         23.3
# 2016-01-03          NaN         36.8         34.3         22.7         16.0
# 2016-01-04          NaN         29.4         27.6         11.2         -4.7
# 2016-01-05          NaN         20.4         31.5          6.5        -13.5
#
#             01084099999  01088799999  01112099999  01135099999  01152099999  \
# 2016-01-01         26.4         45.2         39.6         36.0         42.1
# 2016-01-02         23.6         44.2         35.1         30.8         38.2
# 2016-01-03         21.8         35.8         28.1         18.5         28.6
# 2016-01-04         -3.8         35.1         20.3         12.6         17.6
# 2016-01-05         -6.1         35.4         21.6         10.6         20.4
#
#             ...  99999953182  99999954783  99999954856  99999963829  \
# 2016-01-01  ...         21.8         31.2          NaN         55.8
# 2016-01-02  ...         29.9         30.0          NaN         47.7
# 2016-01-03  ...         33.1         33.2          NaN         46.5
# 2016-01-04  ...         33.3         24.9          NaN         46.8
# 2016-01-05  ...         33.3         13.5          NaN         41.5
#
#             99999963867  99999963897  99999992821  99999994044  99999994081  \
# 2016-01-01         37.1         45.6         74.8         23.6         21.4
# 2016-01-02         36.8         42.3         67.9         33.4         19.9
# 2016-01-03         35.9         41.1         60.6         37.0         14.1
# 2016-01-04         35.1         41.0         54.9         35.5         16.2
# 2016-01-05         31.4         36.6         62.1         40.1         16.5
#
#             99999996404
# 2016-01-01         20.9
# 2016-01-02          9.0
# 2016-01-03         19.9
# 2016-01-04          9.8
# 2016-01-05         -9.4
#
# [5 rows x 1348 columns]

# %%
## plot the locations on the sphere

# %%
# locations with nan?
locations = pd.DataFrame(locations).T
locations.columns = ['LAT','LONG']

locations.head()
# Out:
#                    LAT       LONG
# 00702699999   0.000000   0.000000
# 01007099999  78.916667  11.933333
# 01023199999  64.350000   7.800000
# 01037099999  69.383333  20.283333
# 01058099999  69.566667  23.533333

# %%
has_loc_stations = list(locations[locations.isna().sum(axis = 1) == 0].index)
cleaned_aggregated_data = year_aggregated_data.loc[:, has_loc_stations]

cleaned_locations = locations[locations.isna().sum(axis = 1) == 0]

# %%
cleaned_locations_rad = np.radians(cleaned_locations)

# %%
### how to create dynamic network? Need a normalized distance matrix.

# %%
df = cleaned_locations

BBox = ((-180.,180.,-90.,90.))

import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 12})
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (20,5),gridspec_kw={'width_ratios': [1,1,1.5]})
ax1.plot(year_aggregated_data.isna().sum(axis = 1))
ax1.set_ylabel('# Stations with Missing Data')
ax1.set_xlabel('Date')
ax1.set_title('Missing Station Data by Date')
fig.autofmt_xdate(rotation=45)
## There's no data for 2018? - all good. DateTime Index issues.

ax2.hist(year_aggregated_data.isna().sum(axis = 0))
ax2.set_xlabel('# Dates with missing data')
ax2.set_ylabel('# Stations')
ax2.set_title('Distribution of stations by missing days')

ax3.scatter(df.LONG, df.LAT, zorder = 1, alpha = 0.2, c = 'r', s = 5)
ax3.set_xlabel('Longitude')
ax3.set_ylabel('Latitude')
#wmp = plt.imread('../Images/map.jpg')
#ax.imshow(wmp, zorder = 0, extent = BBox)
ax3.set_title('Worldwide Station Locations')

plt.savefig('NOAA_analysis_data_summary.png')

# %%
### save data
cleaned_aggregated_data.to_pickle('../data/NOAA_aggregated_temp_data.pkl')
cleaned_locations_rad.to_pickle('../data/NOAA_aggregated_locations_radians.pkl')
cleaned_locations.to_pickle('../data/NOAA_aggregated_locations.pkl')

# %% [markdown]
# ## Sliding window analysis

# %%
import pandas as pd
import numpy as np
cleaned_aggregated_data = pd.read_pickle('../data/NOAA_aggregated_temp_data.pkl')
cleaned_locations_rad = pd.read_pickle('../data/NOAA_aggregated_locations_radians.pkl')
cleaned_locations = pd.read_pickle('../data/NOAA_aggregated_locations.pkl')

# %%
from haversine import haversine_vector, Unit

# create list of node weights, list of edge weights, 
node_wts = []
edge_wts = []

# iterate over the rows of the aggregated data.
for time, row in cleaned_aggregated_data.iterrows():
    
    # get nonzero station numbers
    nodes = row[~np.isnan(row)]
    node_locations = cleaned_locations.loc[nodes.index.astype(str),:]
    
    ## convert this to distances between nodes
    dists = haversine_vector(node_locations.values, node_locations.values, comb = True)
    
    N = len(dists)
    radius = 6371. ## radius of the earth.
    threshold = np.sqrt((np.log(N)+8)/(np.pi*N))*radius
    
    ## convert these distances to filtration birthtimes
    filt_birthtimes = np.where(dists < threshold, -np.inf, np.inf)
    
    node_wts.append(nodes)
    edge_wts.append(filt_birthtimes)

# %%
import pickle

# %%
with open('node_wts_NOAA_analysis.pkl', 'wb') as f:
    pickle.dump(node_wts, f) 
    
with open('edge_wts_NOAA_analysis.pkl', 'wb') as f:
    pickle.dump(edge_wts, f)

# %%
import pickle
with open('node_wts_NOAA_analysis.pkl', 'rb') as f:
     node_wts = pickle.load(f) 
    
with open('edge_wts_NOAA_analysis.pkl', 'rb') as f:
     edge_wts = pickle.load(f)

# %%
from __future__ import division
import numpy as np
import sys
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.distance import squareform
import importlib
import scipy.spatial as sp

## Load in sphere code
sys.path.append('../../data/simple_egs/')
import PlaneExample as plane
importlib.reload(plane)

## Load in d.n. analysis code
sys.path.append('../../src/')
import graph_fns as gf
import persistence_fns as pf
import sliding_window_fns as sw
from ripser import ripser
from persim import plot_diagrams
from sklearn import manifold

from matplotlib.lines import Line2D
import time 

importlib.reload(pf)
# Out:
# <module 'persistence_fns' from '../../src/persistence_fns.py'>

# %%
from scipy import sparse
edge_wts = [sparse.coo_matrix(x) for x in edge_wts]
node_wts = [x.values for x in node_wts]
print(len(edge_wts))
print(len(node_wts))
# Out:
# 1461
# 1461

# %%
import multiprocessing as mp
from joblib import Parallel, delayed
from scipy import sparse

## why is this taking so long?
start = time.time()
filtration_matrix = list(map(lambda n, e: pf.get_filtration(n, e), node_wts, edge_wts))
end = time.time()
print("Converting to filtration matrices", end - start)
# Out:
# Converting to filtration matrices 108.30720615386963

# %%
# with open('filt_mats_NOAA_analysis.pkl', 'wb') as f:
#     pickle.dump(filtration_matrix, f)

# %%
start = time.time()
num_cores = mp.cpu_count() - 4
barcodes = Parallel(n_jobs = num_cores)(delayed(pf.get_rips_complex)(filt) for filt in filtration_matrix)
end = time.time()
print("Computing barcodes", end - start)
# Out:
# Computing barcodes 184.49162793159485

# %%
# with open('dgms_NOAA_analysis.pkl', 'wb') as f:
#     pickle.dump(barcodes, f) 

#with open('dgms_NOAA_analysis.pkl', 'rb') as f:
#    barcodes = pickle.load(f)

# %%
#what do the diagrams look like?

# %%
start = time.time()
bn_dist_matrix = pf.get_bottleneck_dist_matrix(barcodes) ### also look at the Wasserstein distances
end = time.time()

### might also want to parallelize this.
print("Computing bottleneck", end - start)
# Out:
# Computing Row 0
# Computing Row 1
# Computing Row 2
# Computing Row 3
# Computing Row 4
# Computing Row 5
# Computing Row 6
# Computing Row 7
# Computing Row 8
# Computing Row 9
# Computing Row 10
# Computing Row 11
# Computing Row 12
# Computing Row 13
# Computing Row 14
# Computing Row 15
# Computing Row 16
# Computing Row 17
# Computing Row 18
# Computing Row 19
# Computing Row 20
# Computing Row 21
# Computing Row 22
# Computing Row 23
# Computing Row 24
# Computing Row 25
# Computing Row 26
# Computing Row 27
# Computing Row 28
# Computing Row 29
# Computing Row 30
# Computing Row 31
# Computing Row 32
# Computing Row 33
# Computing Row 34
# Computing Row 35
# Computing Row 36
# Computing Row 37
# Computing Row 38
# Computing Row 39
# Computing Row 40
# Computing Row 41
# Computing Row 42
# Computing Row 43
# Computing Row 44
# Computing Row 45
# Computing Row 46
# Computing Row 47
# Computing Row 48
# Computing Row 49
# Computing Row 50
# Computing Row 51
# Computing Row 52
# Computing Row 53
# Computing Row 54
# Computing Row 55
# Computing Row 56
# Computing Row 57
# Computing Row 58
# Computing Row 59
# Computing Row 60
# Computing Row 61
# Computing Row 62
# Computing Row 63
# Computing Row 64
# Computing Row 65
# Computing Row 66
# Computing Row 67
# Computing Row 68
# Computing Row 69
# Computing Row 70
# Computing Row 71
# Computing Row 72
# Computing Row 73
# Computing Row 74
# Computing Row 75
# Computing Row 76
# Computing Row 77
# Computing Row 78
# Computing Row 79
# Computing Row 80
# Computing Row 81
# Computing Row 82
# Computing Row 83
# Computing Row 84
# Computing Row 85
# Computing Row 86
# Computing Row 87
# Computing Row 88
# Computing Row 89
# Computing Row 90
# Computing Row 91
# Computing Row 92
# Computing Row 93
# Computing Row 94
# Computing Row 95
# Computing Row 96
# Computing Row 97
# Computing Row 98
# Computing Row 99
# Computing Row 100
# Computing Row 101
# Computing Row 102
# Computing Row 103
# Computing Row 104
# Computing Row 105
# Computing Row 106
# Computing Row 107
# Computing Row 108
# Computing Row 109
# Computing Row 110
# Computing Row 111
# Computing Row 112
# Computing Row 113
# Computing Row 114
# Computing Row 115
# Computing Row 116
# Computing Row 117
# Computing Row 118
# Computing Row 119
# Computing Row 120
# Computing Row 121
# Computing Row 122
# Computing Row 123
# Computing Row 124
# Computing Row 125
# Computing Row 126
# Computing Row 127
# Computing Row 128
# Computing Row 129
# Computing Row 130
# Computing Row 131
# Computing Row 132
# Computing Row 133
# Computing Row 134
# Computing Row 135
# Computing Row 1428
# Computing Row 1429
# Computing Row 1430
# Computing Row 1431
# Computing Row 1432
# Computing Row 1433
# Computing Row 1434
# Computing Row 1435
# Computing Row 1436
# Computing Row 1437
# Computing Row 1438
# Computing Row 1439
# Computing Row 1440
# Computing Row 1441
# Computing Row 1442
# Computing Row 1443
# Computing Row 1444
# Computing Row 1445
# Computing Row 1446
# Computing Row 1447
# Computing Row 1448
# Computing Row 1449
# Computing Row 1450
# Computing Row 1451
# Computing Row 1452
# Computing Row 1453
# Computing Row 1454
# Computing Row 1455
# Computing Row 1456
# Computing Row 1457
# Computing Row 1458
# Computing Row 1459
# Computing Row 1460
# Computing bottleneck 3403.5910170078278

# %%
with open('bn_dist_matrix_NOAA_analysis.pkl', 'wb') as f:
    pickle.dump(bn_dist_matrix, f) 

#with open('bn_dist_matrix_NOAA_analysis.pkl', 'rb') as f:
#    bn_dist_matrix = pickle.load(f)

# %%
# save this computation?

# %%
T = 365
wl = 1.0*T
step_size = 1
d = 60
swe = sw.sliding_window(range(len(barcodes)), d=d, tau= int(wl/(d*step_size)),
                                    max_index = int(3.0*T/step_size) )

print("Number of points in SW Embedding:", len(swe))
sw_dist_matrix = sw.sw_distance_matrix(swe, bn_dist_matrix)
# Out:
# Number of points in SW Embedding: 1095

# %%
PDs = ripser(sw_dist_matrix, distance_matrix=True, maxdim=1, coeff=3)['dgms']

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams.update({'font.size': 13})

fig = plt.figure(figsize = (18,5))

ax2 = fig.add_subplot(133)
ax2.scatter(PDs[1][:,0],PDs[1][:,1],s = 40, label = 'H1')
ax2.set_title('1-D Homology of Sliding Window Point Cloud')
ax2.legend(loc = 4)
ax2.set_aspect('equal','box')
lims = [
    np.min([ax2.get_xlim(), ax2.get_ylim()]),  # min of both axes
    np.max([ax2.get_xlim(), ax2.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax2.set_ylabel('Death')
ax2.set_xlabel('Birth')
ax2.plot(lims, lims, 'k--', alpha=0.75, zorder=0)
a = PDs[1]
sa = a[(a[:,1] - a[:,0]).argsort()]
ax2.plot(sa[-1,0],sa[-1,1],'ro', linewidth = 160)

ax3 = fig.add_subplot(131)
ax3.imshow(bn_dist_matrix)
ax3.set_title('Bottleneck Distance Matrix')
ax3.set_ylabel('y')
ax3.set_xlabel('x')

ax4 = fig.add_subplot(132)
ax4.imshow(sw_dist_matrix)
ax4.set_title('Sliding Window Distance Matrix')
ax4.set_ylabel('y')
ax4.set_xlabel('x')

plt.savefig('results_NOAA_analysis_nonperturbed.png')

# %%
from sklearn.manifold import MDS
embedding = MDS(n_components=3, dissimilarity='precomputed')
X_transformed = embedding.fit_transform(sw_dist_matrix)
print(X_transformed.shape)


import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_transformed[:,0],X_transformed[:,1],X_transformed[:,2],
           c = np.linspace(0,1,X_transformed.shape[0]),
           cmap = plt.cm.viridis)
# Out:
# (1095, 3)
