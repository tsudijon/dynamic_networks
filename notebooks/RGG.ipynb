# %%
import networkx as nx
import matplotlib.pyplot as plt
import math

N = 5000
G=nx.random_geometric_graph(N, (math.log(N)**1.5/(N*math.pi))**0.5, seed = 17)
#G=nx.random_geometric_graph(N, (math.log(math.log(N))/N)**0.5, seed = 17)

# position is stored as node attribute data for random_geometric_graph
pos=nx.get_node_attributes(G,'pos')


# color by path length from node near center
#p=nx.single_source_shortest_path_length(G,ncenter)

plt.figure(figsize=(20,20))
nx.draw_networkx_edges(G,pos,nodelist=[ncenter],alpha=0.5)
nx.draw_networkx_nodes(G,pos, node_size=2)

plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.axis('off')
plt.savefig('random_geometric_graph.png')
plt.show()
# Out:
# /Users/timothysudijono/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /Users/timothysudijono/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning:
# The is_numlike function was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use isinstance(..., numbers.Number) instead.
#   if cb.is_numlike(alpha):

# %% [markdown]
# ## KNN connectivity

# %%
import sklearn.neighbors as nbr
import numpy as np

# %%
pts = np.array(list(nx.get_node_attributes(G,'pos').values()))

# %%
adj_mat = nbr.kneighbors_graph(pts, n_neighbors = 20)

# %%
knng = nx.from_scipy_sparse_matrix(adj_mat)

# %%
# position is stored as node attribute data for random_geometric_graph
pos=nx.get_node_attributes(G,'pos')
nx.set_node_attributes(knng,pos,'pos')

# color by path length from node near center
#p=nx.single_source_shortest_path_length(G,ncenter)

plt.figure(figsize=(20,20))
nx.draw_networkx_edges(knng,pos,nodelist=[ncenter],alpha=0.5)
nx.draw_networkx_nodes(knng,pos, node_size=2)

plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.axis('off')
plt.savefig('random_geometric_graph.png')
plt.show()
# Out:
# /Users/timothysudijono/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /Users/timothysudijono/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning:
# The is_numlike function was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use isinstance(..., numbers.Number) instead.
#   if cb.is_numlike(alpha):

# %%
# is there a way to quantify this type of regularity? For one thing, degree distribution is very close to constant?
# clumping/ clustering coefficients?
